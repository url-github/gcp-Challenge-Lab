# %% [markdown]
# [Engineer Data in Google Cloud: Challenge Lab](https://www.cloudskillsboost.google/focuses/12379?parent=catalog)

# %% [markdown]
# ![2023-05-27 14_32_09-Dane inżyniera w Google Cloud_ Challenge Lab _ Zwiększenie umiejętności Google C.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-27 14_33_32-Dane inżyniera w Google Cloud_ Challenge Lab _ Zwiększenie umiejętności Google C.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-27 14_54_37-Engineer Data in Google Cloud_ Challenge Lab _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
# taxi_training_data_650
# fare_amount_345
# 1
# $2.0
# fare_model_235

# %%
# qwiklabs-gcp-04-65a353db4663.taxirides.historical_taxi_rides_raw

# %% [markdown]
# ![2023-05-27 14_52_42-Query results – BigQuery – qwiklabs-gcp-04-65a… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-27 15_41_06-Dane inżyniera w Google Cloud_ Challenge Lab _ Zwiększenie umiejętności Google C.png](data:image/png;base64,...)

# %%
SELECT

pickup_datetime pickup_datetime,
pickup_longitude pickuplon,
pickup_latitude pickuplat,
dropoff_longitude dropofflon,
dropoff_latitude dropofflat,
passenger_count passengers,
tolls_amount + fare_amount fare_amount_345



FROM `qwiklabs-gcp-04-65a353db4663.taxirides.historical_taxi_rides_raw`

where trip_distance > 1
and fare_amount < 2.0
and pickup_longitude <> 0
and pickup_latitude <> 0
and dropoff_longitude <> 0
and dropoff_latitude <> 0
and passenger_count > 1


LIMIT 650000
